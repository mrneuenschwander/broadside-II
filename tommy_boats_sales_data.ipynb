# %%
import pandas as pd

# %%
sales_data = pd.read_csv("sales_csv2.csv")
sales_data
# Out:
#      Location  J/B  Product Sale Cashiered Date    Date    Year  \
# 0          MI    J      190854.0         1/1/21  21-Jan  2021.0
# 1          DT    J      194959.0         1/4/21  21-Jan  2021.0
# 2          CO    B      193706.0         1/5/21  21-Jan  2021.0
# 3          CO    B      195046.0         1/5/21  21-Jan  2021.0
# 4          CO    B      195213.0         1/6/21  21-Jan  2021.0
# ...       ...  ...           ...            ...     ...     ...
# 3394       SC  NaN      221943.0         3/3/23  23-Mar  2023.0
# 3395       GR  NaN      224141.0         3/3/23  23-Mar  2023.0
# 3396       ST  NaN      223677.0         3/3/23  23-Mar  2023.0
# 3397       FL  NaN      221082.0         3/2/23  23-Mar  2023.0
# 3398      NaN  NaN           NaN            NaN     NaN     NaN
#
#                Customer  Count          Boat Unnamed: 9  ... Is Finance Deal  \
# 0         Wudyka, Wayne    1.0  MB2L9165L021        NaN  ...             NaN
# ...

# %%
finance_boolean = pd.read_csv("finance_boolean.csv")
finance_boolean.head(10)
# Out:
#   Location  J/B  Product Sale Cashiered Date    Date  Year  \
# 0       LW  NaN        215998        2/28/23  23-Feb  2023
# 1       CC  NaN        223612        2/28/23  23-Feb  2023
# 2       FL  NaN        223620        2/28/23  23-Feb  2023
# 3       FL  NaN        222866        2/28/23  23-Feb  2023
# 4       DT  NaN        218768        2/28/23  23-Feb  2023
# 5       DT  NaN        217572        2/28/23  23-Feb  2023
# 6       CC  NaN        224397        2/28/23  23-Feb  2023
# 7       LW  NaN        223700        2/28/23  23-Feb  2023
# 8       LW  NaN        218734        2/28/23  23-Feb  2023
# 9       MI  NaN        223889        2/28/23  23-Feb  2023
#
#                Customer  Count          Boat Unnamed: 9  ... Is Finance Deal  \
# 0  Wilson, Timothy  Lee      1  MB2W1260L223        NaN  ...           False
# 1        Butchko, Jason      1  MB2L7260D222        NaN  ...           False
# 2          Haynes, Mark      1  AWRA4432I920        NaN  ...            True
# ...

# %%
sales_data.columns
finance_boolean.columns
# Out:
# Index(['Location', 'J/B', 'Product Sale', 'Cashiered Date', 'Date', 'Year',
#        'Customer', 'Count', 'Boat', 'Unnamed: 9', 'Trailer', 'Unnamed: 11',
#        'Engine Serial', 'Product Location', 'Year.1', 'Make', 'Model',
#        'Product Offer Type', 'Trade-In Deficit', 'Deal Cost', ' Deal Retail ',
#        'Price', 'Amount Paid', 'Staff', 'Source', 'Days On Lot', 'Trade-In',
#        'FD Order Number', 'FD Amount', 'FD Reason', 'Is Finance Deal',
#        'Signed PA', 'ESigned PA', 'Finance Checklist', 'NADA Valuation',
#        'Trade Eval', 'Title', 'Proof Of Ownership', 'Bank Payoff',
#        'Other Docs'],
#       dtype='object')

# %%
sales_data["Year.1"]
# Out:
# 0       2021
# 1       2012
# 2       2021
# 3       2020
# 4       2021
#         ...
# 3393    2022
# 3394    2023
# 3395    2023
# 3396    2023
# 3397    2023
# Name: Year.1, Length: 3398, dtype: int64

# %%
scrub_df = sales_data.drop(columns=["J/B", "Product Sale", "Customer", "Count", "Boat", 
                                    "Unnamed: 9", "Trailer", "Unnamed: 11", "Engine Serial", 
                                    "Source", "Trade-In", "FD Order Number", "FD Reason", 
                                    "Signed PA", "ESigned PA", "NADA Valuation",
                                    "Trade Eval", "Title", "Proof Of Ownership",
                                    "Bank Payoff", "Other Docs", "Unnamed: 40", "Unnamed: 41"], axis=1)
scrub_df
# Out:
#      Location Cashiered Date    Date  Year Product Location  Year.1  \
# 0          MI       1/1/2021  Jan-21  2021               MI    2021
# 1          DT       1/4/2021  Jan-21  2021               DT    2012
# 2          CO       1/5/2021  Jan-21  2021               CO    2021
# 3          CO       1/5/2021  Jan-21  2021               MI    2020
# 4          CO       1/6/2021  Jan-21  2021               CO    2021
# ...       ...            ...     ...   ...              ...     ...
# 3393       PX       3/3/2023  Mar-23  2023               PX    2022
# 3394       SC       3/3/2023  Mar-23  2023               SC    2023
# 3395       GR       3/3/2023  Mar-23  2023               GR    2023
# 3396       ST       3/3/2023  Mar-23  2023               ST    2023
# 3397       FL       3/2/2023  Mar-23  2023               FL    2023
#
#             Make                                              Model  \
# 0         Malibu                                             24 MXZ
# ...

# %%
financeNN_df = sales_data.drop(columns=["J/B", "Product Sale", "Customer", "Count", "Boat", 
                                    "Unnamed: 9", "Trailer", "Unnamed: 11", "Engine Serial", 
                                    "Source", "Trade-In", "FD Order Number", "FD Reason", 
                                    "Signed PA", "ESigned PA", "Finance Checklist", "NADA Valuation",
                                    "Trade Eval", "Title", "Proof Of Ownership",
                                    "Bank Payoff", "Other Docs"], axis=1)
financeNN_df["Trade-In Deficit"] = financeNN_df["Trade-In Deficit"].fillna(0)
financeNN_df.to_csv("finance_boolean.csv")

# %%
scrub_df.isnull().sum()
# Out:
# Location                 0
# Cashiered Date           0
# Date                     0
# Year                     0
# Product Location        10
# Year.1                   0
# Make                    10
# Model                   10
# Product Offer Type      10
# Trade-In Deficit       154
# Deal Cost                0
#  Deal Retail             0
# Price                    1
# Amount Paid              0
# Staff                    0
# Days On Lot              0
# FD Amount                0
# Is Finance Deal       3169
# Finance Checklist     3110
# dtype: int64

# %%
scrub_df = scrub_df.drop(columns=["Finance Checklist"], axis=1)

# %%
scrub_df.isnull().sum()
# Out:
# Location                 0
# Cashiered Date           0
# Date                     0
# Year                     0
# Product Location        10
# Year.1                   0
# Make                    10
# Model                   10
# Product Offer Type      10
# Trade-In Deficit       154
# Deal Cost                0
#  Deal Retail             0
# Price                    1
# Amount Paid              0
# Staff                    0
# Days On Lot              0
# FD Amount                0
# Is Finance Deal       3169
# dtype: int64

# %%
maxes_by_day = scrub_df.groupby(["Cashiered Date", "Location"]).max()
maxes_by_day
# Out:
# /Users/mitch/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                            Date  Year  Year.1     Deal Cost  Deal Retail   \
# Cashiered Date Location
# 1/1/2021       MI        Jan-21  2021    2021  $135,258.50   $174,141.00
# 1/10/2022      CO        Jan-22  2022    2022   $90,407.52    113,994.00
#                DT        Jan-22  2022    2022   $37,177.00     48,724.00
#                FL        Jan-22  2022    2017   $87,743.09    103,468.00
# 1/11/2021      CO        Jan-21  2021    2021   $76,727.20    $92,729.00
# ...                         ...   ...     ...           ...           ...
# 9/8/2022       VT        Sep-22  2022    2022  $157,393.04   $188,852.25
# ...

# %%
description_df = scrub_df.groupby(["Location", "Staff"]).mean()
description_df
# Out:
#                                   Year       Year.1  Days On Lot
# Location Staff
# CC       Draves, Matt      2023.000000  2022.800000   171.200000
#          Loudenback, Jake  2023.000000  2022.333333   257.333333
#          Nagy, Mitchell    2023.000000  1733.142857   135.285714
# CH       Ball, Chris       2021.200000  2017.200000    17.000000
#          Boynton, Connor   2021.987342  2020.291139    60.886076
# ...                                ...          ...          ...
# VT       Diaz, Dave        2021.500000  2021.000000    39.500000
#          Draves, Matt      2021.468750  2021.140625   100.375000
#          Lee, Dan          2021.000000  2021.000000    25.000000
#          Loudenback, Jake  2022.000000  2019.800000   103.700000
#          Nagy, Mitchell    2021.758621  2020.931034   133.931034
#
# [101 rows x 3 columns]
